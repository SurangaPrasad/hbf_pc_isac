# %%
from PGA_models import PGA_Unfold_JX_partial, PGA_Unfold_JX
from system_config import *
model1 = PGA_Unfold_JX(step_size_UPGA_J5)
model1.load_state_dict(torch.load(model_file_name_UPGA_J5, map_location=device))    

model2 = PGA_Unfold_JX_partial(step_size_UPGA_J5_PC, Nt, Nrf)
model2.load_state_dict(torch.load(model_file_name_UPGA_J5, map_location=device), strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['mask'], unexpected_keys=[])

# %%
print("Model 1 parameters:")
for name, param in model1.named_parameters():
    print(f"{name}: {param.data}")

print("Model 2 parameters:")
for name, param in model2.named_parameters():
    print(f"{name}: {param.data}")
# Out:
# Model 1 parameters:
# step_size: tensor([[[0.0198, 0.0484],
#          [0.0696, 0.0167],
#          [0.0699, 0.0011],
#          ...,
#          [0.0676, 0.0543],
#          [0.0675, 0.0586],
#          [0.0672, 0.0657]],
#
#         [[0.0194, 0.0100],
#          [0.0696, 0.0100],
#          [0.0699, 0.0100],
#          ...,
#          [0.0676, 0.0100],
#          [0.0675, 0.0100],
#          [0.0672, 0.0100]],
#
#         [[0.0192, 0.0100],
#          [0.0696, 0.0100],
#          [0.0699, 0.0100],
#          ...,
#          [0.0676, 0.0100],
#          [0.0675, 0.0100],
#          [0.0672, 0.0100]],
#
#         [[0.0191, 0.0100],
#          [0.0696, 0.0100],
#          [0.0699, 0.0100],
#          ...,
#          [0.0676, 0.0100],
#          [0.0675, 0.0100],
#          [0.0672, 0.0100]],
#
#         [[0.0190, 0.0100],
#          [0.0696, 0.0100],
#          [0.0699, 0.0100],
#          ...,
#          [0.0676, 0.0100],
#          [0.0675, 0.0100],
#          [0.0672, 0.0100]]])
# Model 2 parameters:
# step_size: tensor([[[0.0198, 0.0484],
#          [0.0696, 0.0167],
#          [0.0699, 0.0011],
#          ...,
#          [0.0676, 0.0543],
#          [0.0675, 0.0586],
#          [0.0672, 0.0657]],
#
#         [[0.0194, 0.0100],
#          [0.0696, 0.0100],
#          [0.0699, 0.0100],
#          ...,
#          [0.0676, 0.0100],
#          [0.0675, 0.0100],
#          [0.0672, 0.0100]],
#
#         [[0.0192, 0.0100],
#          [0.0696, 0.0100],
#          [0.0699, 0.0100],
#          ...,
#          [0.0676, 0.0100],
#          [0.0675, 0.0100],
#          [0.0672, 0.0100]],
#
#         [[0.0191, 0.0100],
#          [0.0696, 0.0100],
#          [0.0699, 0.0100],
#          ...,
#          [0.0676, 0.0100],
#          [0.0675, 0.0100],
#          [0.0672, 0.0100]],
#
#         [[0.0190, 0.0100],
#          [0.0696, 0.0100],
#          [0.0699, 0.0100],
#          ...,
#          [0.0676, 0.0100],
#          [0.0675, 0.0100],
#          [0.0672, 0.0100]]])

# %%
import numpy as np
import matplotlib.pyplot as plt

# step_size shape: [n_iter_inner, n_iter_outer, 2]  -> (mu, lambda)
sz1 = model1.step_size.detach().cpu().numpy()   # FC-trained
sz2 = model2.step_size.detach().cpu().numpy()  # Partial-trained

n_outer = sz1.shape[1]
outer_iters = np.arange(n_outer)

# Average over inner iterations (jj), separately for mu and lambda
mu1_avg  = sz1[:, :, 0].mean(axis=0)
lam1_avg = sz1[:, :, 1].mean(axis=0)

mu2_avg  = sz2[:, :, 0].mean(axis=0)
lam2_avg = sz2[:, :, 1].mean(axis=0)

fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))

axes[0].plot(outer_iters, mu1_avg, label='Fixed-UPGA (FC-trained)', color='red', linewidth=2)
axes[0].plot(outer_iters, mu2_avg, label='Fixed-UPGA-PC (partial-trained)', color='green', linewidth=2)
axes[0].set_xlabel('Outer iteration (ii)')
axes[0].set_ylabel(r'Average $\mu$ (mean over inner iters)')
axes[0].set_title('Average communications step size vs outer iteration')
axes[0].legend()
axes[0].grid(True)

axes[1].plot(outer_iters, lam1_avg, label='Fixed-UPGA (FC-trained)', color='red', linewidth=2)
axes[1].plot(outer_iters, lam2_avg, label='Fixed-UPGA-PC (partial-trained)', color='green', linewidth=2)
axes[1].set_xlabel('Outer iteration (ii)')
axes[1].set_ylabel(r'Average $\lambda$ (mean over inner iters)')
axes[1].set_title('Average sensing step size vs outer iteration')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
from utility import get_data_tensor
H_train, H_test0 = get_data_tensor(data_source)
H_test = H_train[:, :test_size, :, :]
sum_rate_UPGA_partial_J5, crb_UPGA_partial_J5, F_UPGA_partial_J5, W_UPGA_partial_J5, gradient_norm_history_UPGA_partial_J5, gradient_norm_history_UPGA_partial_J5_W = model2.execute_PGA(H_test, xi_0, A_dot, R_N_inv,
                                                                                        snr,
                                                                                        n_iter_outer,
                                                                                        n_iter_inner_J5)

# %%
sum_rate_UPGA_J5, crb_UPGA_J5, F_UPGA_J5, W_UPGA_J5, gradient_norm_history_UPGA_J5, gradient_norm_history_UPGA_J5_W = model1.execute_PGA(H_test, xi_0, A_dot, R_N_inv,
                                                                                        snr,
                                                                                        n_iter_outer,
                                                                                        n_iter_inner_J5)

# %%
F_UPGA_J5
# Out:
# tensor([[[[-0.8423+0.5390j,  0.5592+0.8290j, -0.0978-0.9952j,  0.8417+0.5399j],
#           [ 0.8017-0.5977j,  0.1959+0.9806j, -0.2399+0.9708j, -0.6634+0.7483j],
#           [-0.9418+0.3361j,  0.2858+0.9583j,  0.3079-0.9514j, -0.6958+0.7182j],
#           ...,
#           [ 0.2641-0.9645j, -0.8212+0.5706j, -0.9067-0.4218j,  0.7766+0.6299j],
#           [-0.8277+0.5612j,  0.9125+0.4091j, -0.7288+0.6848j, -0.4926-0.8702j],
#           [-0.3705+0.9288j, -0.3817-0.9243j, -0.7007+0.7134j, -0.1184+0.9930j]],
#
#          [[-0.5605-0.8282j,  0.6366+0.7712j, -0.5980-0.8015j,  0.8960+0.4441j],
#           [-0.1619+0.9868j,  0.8788+0.4772j, -0.8189+0.5739j,  0.9830+0.1838j],
#           [ 0.5715-0.8206j,  0.3592+0.9332j, -0.6853+0.7282j,  0.6362+0.7715j],
#           ...,
#           [ 0.9265+0.3762j,  0.9310+0.3651j,  0.9317+0.3632j,  0.9804+0.1971j],
#           [ 0.9619-0.2734j, -0.2326-0.9726j, -0.8517+0.5241j,  0.2879+0.9576j],
#           [-0.0449-0.9990j, -0.6221+0.7830j,  0.4854+0.8743j, -0.8674-0.4976j]],
#
#          [[ 0.6676-0.7445j,  0.0904+0.9959j,  0.0962+0.9954j, -0.9873+0.1588j],
#           [-0.9986-0.0525j, -0.9591+0.2830j, -0.0799+0.9968j,  0.1373+0.9905j],
#           [-0.6794+0.7338j,  0.4020-0.9156j,  0.5401+0.8416j, -0.9097+0.4152j],
#           ...,
#           [-0.1707+0.9853j, -0.9971-0.0760j, -0.9609-0.2769j, -0.3313-0.9435j],
#           [-0.0654-0.9979j,  0.9820-0.1889j,  0.9862+0.1656j, -0.5610+0.8278j],
#           [ 0.5843+0.8115j,  0.5536-0.8328j,  0.8581-0.5134j,  0.7197+0.6942j]],
#
#          ...,
#
#          [[-0.1042+0.9946j,  0.0589+0.9983j, -0.1204+0.9927j, -0.9814-0.1921j],
#           [-0.7952-0.6063j,  0.2966-0.9550j,  0.1138-0.9935j, -0.0116-0.9999j],
#           [ 0.9994-0.0357j, -0.2932-0.9561j, -0.9703+0.2420j,  0.2159-0.9764j],
#           ...,
#           [ 0.0254-0.9997j, -0.0038-1.0000j, -0.9660+0.2584j,  0.4048-0.9144j],
#           [-0.9970+0.0778j, -0.9234+0.3838j,  0.6289+0.7775j, -0.3106+0.9505j],
#           [-0.6390+0.7692j,  0.9939-0.1099j,  0.9871-0.1603j,  0.7890+0.6144j]],
#
#          [[-0.6277+0.7784j,  0.7903+0.6127j, -0.9987+0.0506j,  0.9962-0.0875j],
#           [-0.7148-0.6994j, -0.2280+0.9737j, -0.8425+0.5387j,  0.8989+0.4382j],
#           [ 0.9742-0.2256j,  0.5446+0.8387j,  0.9072-0.4207j, -0.8524+0.5229j],
#           ...,
#           [-0.2559-0.9667j, -0.8917-0.4526j, -0.4405-0.8977j, -0.9199-0.3921j],
#           [-0.0871+0.9962j,  0.9994+0.0341j,  0.9955-0.0953j,  0.2569+0.9664j],
#           [-0.0625-0.9980j, -0.3496-0.9369j,  0.4277-0.9039j,  0.8853-0.4651j]],
#
#          [[-0.9480-0.3184j,  0.5727+0.8197j, -0.7398-0.6728j,  0.9089-0.4171j],
#           [ 0.3579-0.9338j, -0.9993-0.0377j,  0.7914+0.6113j, -0.9667-0.2558j],
#           [-0.9303-0.3669j,  0.3834+0.9236j,  0.4267-0.9044j, -0.1795+0.9837j],
#           ...,
#           [-0.9988-0.0480j, -0.9774-0.2113j,  0.2303+0.9731j, -0.8789-0.4770j],
#           [ 0.6121-0.7908j,  0.8095+0.5871j,  0.4415-0.8973j,  0.9816+0.1911j],
#           [-0.7320+0.6813j, -0.5809-0.8139j, -0.9816+0.1912j, -0.7205-0.6935j]]]],
#        grad_fn=<DivBackward0>)

# %%
F_UPGA_partial_J5
# Out:
# tensor([[[[-0.3698+0.9291j,  0.0000+0.0000j,  0.0000+0.0000j,  0.4524+0.8918j],
#           [ 0.9345-0.3560j,  0.0000+0.0000j,  0.0000+0.0000j, -0.1471+0.9891j],
#           [-0.8944+0.4472j,  0.0000+0.0000j,  0.0000+0.0000j, -0.9389-0.3442j],
#           ...,
#           [ 0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,  0.9998-0.0211j],
#           ...,
#           [ 0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j, -0.9607+0.2775j],
#           [ 0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j,  0.9615+0.2746j],
#           [ 0.0000+0.0000j,  0.0000+0.0000j,  0.0000+0.0000j, -0.4711-0.8821j]]]],
#        grad_fn=<MulBackward0>)

# %%
import numpy as np
import matplotlib.pyplot as plt

def get_outer_iter_curve(tensor):
    """
    tensor: shape [n_iter_outer, B]
    Returns: mean-over-batch curve of shape [n_iter_outer]
    """
    return tensor.mean(dim=1).detach().cpu().numpy()

# Sum rate curves
rate_curve_FC      = get_outer_iter_curve(sum_rate_UPGA_J5)
rate_curve_partial = get_outer_iter_curve(sum_rate_UPGA_partial_J5)

# CRB curves
crb_curve_FC      = get_outer_iter_curve(crb_UPGA_J5)
crb_curve_partial = get_outer_iter_curve(crb_UPGA_partial_J5)

n_iter_outer = sum_rate_UPGA_J5.shape[0]
outer_iters = np.arange(1, n_iter_outer + 1)

# --- Sum rate plot ---
plt.figure(figsize=(8, 5))
plt.plot(outer_iters, rate_curve_FC, label='Fixed-UPGA (FC-trained)', color='red', marker='D', markersize=4, linewidth=2)
plt.plot(outer_iters, rate_curve_partial, label='Fixed-UPGA-PC (partial-trained)', color='green', marker='^', markersize=4, linewidth=2)
plt.xlabel('Number of iterations/layers (I)')
plt.ylabel('Sum rate')
plt.title('Sum rate vs outer iteration')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# --- CRB plot ---
plt.figure(figsize=(8, 5))
plt.plot(outer_iters, crb_curve_FC, label='Fixed-UPGA (FC-trained)', color='red', marker='D', markersize=4, linewidth=2)
plt.plot(outer_iters, crb_curve_partial, label='Fixed-UPGA-PC (partial-trained)', color='green', marker='^', markersize=4, linewidth=2)
plt.xlabel('Number of iterations/layers (I)')
plt.ylabel('CRB')
plt.title('CRB vs outer iteration')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# OMEGA should already be defined via `from system_config import *`
# If not, set it explicitly here:
# OMEGA = 0.5

def get_outer_iter_curve(tensor):
    return tensor.mean(dim=1).detach().cpu().numpy()

rate_curve_FC      = get_outer_iter_curve(sum_rate_UPGA_J5)
rate_curve_partial = get_outer_iter_curve(sum_rate_UPGA_partial_J5)

crb_curve_FC      = get_outer_iter_curve(crb_UPGA_J5)
crb_curve_partial = get_outer_iter_curve(crb_UPGA_partial_J5)

n_iter_outer = sum_rate_UPGA_J5.shape[0]
outer_iters = np.arange(1, n_iter_outer + 1)

# --- Objective: OMEGA * rate + log(1/CRB)  (matches ωR + log(CRLB⁻¹) convention) ---
objective_FC      = OMEGA * rate_curve_FC      + crb_curve_FC
objective_partial = OMEGA * rate_curve_partial + crb_curve_partial

plt.figure(figsize=(8, 5))
plt.plot(outer_iters, objective_FC, label='Fixed-UPGA (FC-trained)', color='red', marker='D', markersize=4, linewidth=2)
plt.plot(outer_iters, objective_partial, label='Fixed-UPGA-PC (partial-trained)', color='green', marker='^', markersize=4, linewidth=2)
plt.xlabel('Number of iterations/layers (I)')
plt.ylabel(r'$\omega R + \log(\mathrm{CRLB}^{-1})$')
plt.title('Objective vs outer iteration')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
