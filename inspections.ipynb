# %%
from scipy.io import loadmat

directory = "dataset/8TX_4UE_4RF"

test_channel_data = loadmat(f"{directory}/test_data_matlab.mat")

# %%
test_channel_data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Cbar', 'DeltaF', 'H_test', 'H_train', 'J', 'K', 'Nr', 'Nt', 'Pd_theta', 'Pt', 'SNR_vec', 'a', 'at', 'beam_width', 'channel_type', 'delta', 'f0', 'fk', 'fmax', 'ii', 'k', 'l', 'n_test', 'n_trial', 'phi', 'ss', 'system_config_channel', 'system_config_radar', 'target_DoA', 'theta', 'tt'])

# %%
X = test_channel_data["J"]
X.shape
# Out:
# (8, 8, 1, 7)

# %%
import torch

model_path = "model/8TX_4UE_4RF_001/UPGA_J10.pth"
checkpoint = torch.load(model_path, map_location="cpu")
print(checkpoint.keys())
# Out:
# odict_keys(['step_size'])

# %%
checkpoint = torch.load(model_path, map_location="cpu")
print(checkpoint)
# Out:
# OrderedDict({'step_size': tensor([[[0.0052, 0.0187],
#          [0.0125, 0.0159],
#          [0.0202, 0.0151],
#          ...,
#          [0.0144, 0.0193],
#          [0.0130, 0.0072],
#          [0.0109, 0.0122]],
#
#         [[0.0052, 0.0100],
#          [0.0127, 0.0100],
#          [0.0203, 0.0100],
#          ...,
#          [0.0145, 0.0100],
#          [0.0130, 0.0100],
#          [0.0109, 0.0100]],
#
#         [[0.0052, 0.0100],
#          [0.0127, 0.0100],
#          [0.0203, 0.0100],
#          ...,
#          [0.0146, 0.0100],
#          [0.0131, 0.0100],
#          [0.0109, 0.0100]],
#
#         ...,
#
#         [[0.0052, 0.0100],
#          [0.0128, 0.0100],
#          [0.0203, 0.0100],
#          ...,
#          [0.0147, 0.0100],
#          [0.0131, 0.0100],
#          [0.0109, 0.0100]],
#
#         [[0.0052, 0.0100],
#          [0.0128, 0.0100],
#          [0.0202, 0.0100],
#          ...,
#          [0.0147, 0.0100],
#          [0.0131, 0.0100],
# ...
