# %%
from PGA_models import *
from system_config import *

H_train, H_test0 = get_data_tensor(data_source)
model_UPGA_partial = PGA_Unfold_JX_partial(step_size_UPGA_J10, 64, 4)

H_shuffled = torch.transpose(H_train, 0, 1)[np.random.permutation(len(H_train[0]))]
print(f'The size of the training data is: {H_shuffled.shape}')
# Out:
# The size of the training data is: torch.Size([224, 1, 4, 64])

# %%
# _, F, W = initialize(H_shuffled[0], Pt, initial_normalization)
snr_dB_train = 12
snr_train = 10 ** (snr_dB_train / 10)
print(snr_train)
H = H_shuffled[0:1].transpose(0, 1)
print(f'The size of the first training sample is: {H.shape}')
_, F, W = initialize(H, snr_train, initial_normalization)

# __, __, __, F, W, __, _ = model_UPGA_partial.execute_PGA(H, xi_0, A_dot, R_N_inv, snr_train, n_iter_outer, step_size_UPGA_J10.shape[0], track_metrics=False)
print(f'F: {F}, W: {W}')
# Out:
# 15.848931924611133
# The size of the first training sample is: torch.Size([1, 1, 4, 64])
# F: tensor([[[[-0.0481+9.9884e-01j,  0.4404-8.9779e-01j, -0.9872+1.5927e-01j,
#             0.3572-9.3403e-01j],
#           [ 0.9843+1.7660e-01j,  0.9487-3.1614e-01j, -0.6420+7.6668e-01j,
#            -0.9811-1.9346e-01j],
#           [-0.4152+9.0972e-01j, -0.8748-4.8454e-01j,  0.6929-7.2106e-01j,
#            -0.2249-9.7439e-01j],
#           [-0.6004-7.9971e-01j,  0.8595+5.1112e-01j, -0.4297-9.0299e-01j,
#            -0.0239+9.9971e-01j],
#           [-0.8399+5.4277e-01j,  0.4012-9.1599e-01j, -0.9898-1.4252e-01j,
#             0.8015-5.9797e-01j],
#           [ 0.6628+7.4883e-01j, -0.0946+9.9552e-01j, -0.0496+9.9877e-01j,
#             0.7339+6.7923e-01j],
#           [-0.1760-9.8439e-01j, -0.4148-9.0991e-01j,  0.9831+1.8303e-01j,
#            -0.8763-4.8173e-01j],
#           [-0.3185+9.4794e-01j,  0.3204+9.4730e-01j, -0.8667-4.9880e-01j,
#            -0.5224+8.5269e-01j],
# ...
